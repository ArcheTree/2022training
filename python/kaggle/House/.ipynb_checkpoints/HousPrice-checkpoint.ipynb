# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import numpy as np
print(pd.__version__ , sns.__version__,np.__version__)
# Out:
# 1.4.4 0.12.0 1.23.2

# %%
pd.set_option('display.max_seq_items',None)
train_df=pd.read_csv("data/train.csv")
test_df=pd.read_csv("data/test.csv")
print(train_df.shape,test_df.shape)
# Out:
# (1460, 81) (1459, 80)

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train_df.describe(include="object")
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
train_df[["ScreenPorch","SalePrice"]].groupby(["ScreenPorch"]).mean()
# Out:
#                  SalePrice
# ScreenPorch
# 0            178888.061756
# 40           121000.000000
# 53           165000.000000
# 60           143000.000000
# 63           121600.000000
# ...                    ...
# 385          160000.000000
# 396          275000.000000
# 410          475000.000000
# 440          250000.000000
# 480          256000.000000
#
# [76 rows x 1 columns]

# %%
combine=[train_df,test_df]
for dataset in combine:
    print(dataset.isna().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
train_df.describe(include="object")
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train_df[["MSZoning","SalePrice"]].groupby(["MSZoning"]).mean()
# Out:
#               SalePrice
# MSZoning
# C (all)    74528.000000
# FV        214014.061538
# RH        131558.375000
# RL        191004.994787
# RM        126316.830275

# %%
train_df['MoSold'].value_counts()
# Out:
# 6     253
# 7     234
# 5     204
# 4     141
# 8     122
# 3     106
# 10     89
# 11     79
# 9      63
# 12     59
# 1      58
# 2      52
# Name: MoSold, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.heatmap(train_df.isnull(), yticklabels=False, cmap='viridis')
plt.show()

# %%
all_data_na = (train_df.isnull().sum()/len(train_df))*100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:15]
missing_data = pd.DataFrame({'Missing Data' : all_data_na})
missing_data
# Out:
#               Missing Data
# PoolQC           99.520548
# MiscFeature      96.301370
# Alley            93.767123
# Fence            80.753425
# FireplaceQu      47.260274
# LotFrontage      17.739726
# GarageType        5.547945
# GarageYrBlt       5.547945
# GarageFinish      5.547945
# GarageQual        5.547945
# GarageCond        5.547945
# BsmtExposure      2.602740
# BsmtFinType2      2.602740
# BsmtFinType1      2.534247
# BsmtCond          2.534247

# %%
train_df[(train_df['GarageYrBlt'].isnull()) & (train_df['YearBuilt'] >1800)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL         65.0     6040   Pave   NaN      Reg
# 48      49         190       RM         33.0     4456   Pave   NaN      Reg
# 78      79          90       RL         72.0    10778   Pave   NaN      Reg
# 88      89          50  C (all)        105.0     8470   Pave   NaN      IR1
# 89      90          20       RL         60.0     8070   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 1407  1408          20       RL          NaN     8780   Pave   NaN      IR1
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
#
# ...

# %%
fig,ax = plt.subplots(figsize=(14,8))
sns.barplot(x=all_data_na.index ,y=all_data_na)
plt.xticks(rotation = 90)
plt.xlabel('Features')
plt.ylabel('Ratio of Missing Values')
plt.title('Missing Values in Training Set (Ratio)')
plt.show()

# %%
plt.figure(figsize=(14,8))
train_df.corr()['SalePrice'].sort_values()[:-1].plot(kind='bar')
plt.show()

# %%
train_df.corr()['SalePrice'].sort_values(ascending=False)[1:]
# Out:
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# ...

# %%
plt.figure(figsize=(14,8))
sns.distplot(train_df['SalePrice'], kde=True, bins=50)
plt.show()
# Out:
# C:\Users\KB\AppData\Local\Temp\ipykernel_11972\328497871.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df['SalePrice'], kde=True, bins=50)

# %%
fig, axes = plt.subplots(1,2, figsize=(18,8))
sns.scatterplot(x = 'SalePrice', y= 'YearBuilt', data=train_df, ax=axes[0])
sns.scatterplot(x = 'SalePrice', y='YearRemodAdd', data=train_df, ax=axes[1])
axes[0].set_title('SalePrice vs YearBuilt')
axes[1].set_title('SalePrice vs Year Remodeled')
plt.show()

# %%
train_df[train_df["SalePrice"]>600000]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 898       3   2010       New        Partial     611657
# ...

# %%
train_df=train_df.drop(index=[691,898,1169,1182])

# %%
fig, axes = plt.subplots(1,2, figsize=(18,8))
sns.scatterplot(x = 'SalePrice', y= 'YearBuilt', data=train_df, ax=axes[0])
sns.scatterplot(x = 'SalePrice', y='YearRemodAdd', data=train_df, ax=axes[1])
axes[0].set_title('SalePrice vs YearBuilt')
axes[1].set_title('SalePrice vs Year Remodeled')
plt.show()

# %%
print(train_df['GarageCars'].value_counts())
# Out:
# 2    824
# 1    369
# 3    177
# 0     81
# 4      5
# Name: GarageCars, dtype: int64

# %%
print(train_df['GarageCars'].isnull().sum())
# Out:
# 0

# %%
print(train_df['GrLivArea'].value_counts())
print(train_df['GrLivArea'].isnull().sum())
# Out:
# 864     22
# 1040    14
# 894     11
# 1456    10
# 848     10
#         ..
# 2119     1
# 2344     1
# 1244     1
# 4676     1
# 1256     1
# Name: GrLivArea, Length: 857, dtype: int64
# 0

# %%
fig,ax = plt.subplots(1, figsize=(14,8))
sns.countplot(data = train_df, x='GarageCars')
plt.show()

# %%
fig = plt.subplots(1, figsize=(14,8))
sns.histplot(x=train_df['GrLivArea'],  bins=60)
plt.show()

# %%
print(train_df['TotalBsmtSF'].value_counts())
print(train_df['TotalBsmtSF'].isnull().sum())
# Out:
# 0       37
# 864     35
# 672     17
# 912     15
# 1040    14
#         ..
# 1838     1
# 1581     1
# 707      1
# 611      1
# 1542     1
# Name: TotalBsmtSF, Length: 718, dtype: int64
# 0

# %%
fig,ax = plt.subplots(1,2, figsize=(14,8))
sns.histplot(x=train_df['TotalBsmtSF'], ax=ax[0], bins=60)

ax[0].set_title('TotalBsmtSF size')

plt.show()

# %%
train_df[train_df["TotalBsmtSF"]>6000]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1298      1   2008       New        Partial     160000
#
# [1 rows x 81 columns]

# %%
train_df=train_df.drop(index=[1298])

# %%
fig,ax = plt.subplots(1,2, figsize=(14,8))
sns.histplot(x=train_df['TotalBsmtSF'], ax=ax[0], bins=60)

ax[0].set_title('TotalBsmtSF size')

plt.show()

# %%
plt.figure(figsize=(14,8))
train_df.corr()['SalePrice'].sort_values()[:-1].plot(kind='bar')
plt.show()

# %%
g=sns.FacetGrid(train_df,col="BldgType")
g.map(plt.hist, "OverallQual",bins=20)

# %%
g=sns.FacetGrid(train_df,col="CentralAir")
g.map(plt.hist, "GrLivArea",bins=20)

# %%
g=sns.FacetGrid(train_df,col="HouseStyle")
g.map(plt.hist, "OverallQual",bins=20)

# %%
sim=train_df.drop("PoolQC",axis=1)

# %%
sim=train_df.drop("MiscFeature",axis=1)

# %%
sim=sim.drop("PoolQC",axis=1)

# %%
sim=sim.drop("Alley",axis=1)

# %%
sim=sim.drop("Fence",axis=1)

# %%
sim.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
sim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1455 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1455 non-null   int64
#  1   MSSubClass     1455 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1196 non-null   float64
#  4   LotArea        1455 non-null   int64
#  5   Street         1455 non-null   object
#  6   LotShape       1455 non-null   object
#  7   LandContour    1455 non-null   object
#  8   Utilities      1455 non-null   object
#  9   LotConfig      1455 non-null   object
#  10  LandSlope      1455 non-null   object
#  11  Neighborhood   1455 non-null   object
#  12  Condition1     1455 non-null   object
#  13  Condition2     1455 non-null   object
#  14  BldgType       1455 non-null   object
#  15  HouseStyle     1455 non-null   object
#  16  OverallQual    1455 non-null   int64
# ...

# %%
sns.set(rc={'figure.figsize':(20,20)})
g=sns.FacetGrid(sim,row="FireplaceQu")
g.map(sns.pointplot,"SalePrice","Fireplaces")
g.add_legend()
# Out:
# C:\Users\KB\miniconda3\lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g=sns.FacetGrid(sim,row="KitchenQual")
g.map(sns.pointplot,"SalePrice","KitchenAbvGr")
g.add_legend()
# Out:
# C:\Users\KB\miniconda3\lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
sim[["KitchenQual","SalePrice"]].groupby(["KitchenQual"],as_index=False).mean()
# Out:
#   KitchenQual      SalePrice
# 0          Ex  318581.354167
# 1          Fa  105565.205128
# 2          Gd  211410.239316
# 3          TA  139962.511565

# %%
combine=[sim,test_df]

# %%
title_mapping={"EX":5,"Gd":4,"TA":3, "Fa":2}
for dataset in combine:
    dataset["KitchenQual"]=dataset["KitchenQual"].map(title_mapping)
    dataset["KitchenQual"]=dataset["KitchenQual"].fillna(0)
sim.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1053  1054          20       RL         68.0     8562   Pave      Reg
# 825    826          20       RL        114.0    14803   Pave      Reg
# 1134  1135          60       RL         57.0     8773   Pave      IR1
# 1354  1355          60       RL          NaN    10316   Pave      IR1
# 253    254          80       RL         85.0     9350   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1053         Lvl    AllPub    Inside  ...             0         0           0
# 825          Lvl    AllPub    Inside  ...             0         0           0
# 1134         HLS    AllPub    Inside  ...             0         0           0
# 1354         Lvl    AllPub    Inside  ...             0         0           0
# 253          Lvl    AllPub    Inside  ...             0         0           0
#
#      PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
plt.figure(figsize=(14,8))
sim.corr()['SalePrice'].sort_values()[:-1].plot(kind='bar')
plt.show()

# %%
sim[["GarageQual","SalePrice"]].groupby(["GarageQual"],as_index=False).mean()
# Out:
#   GarageQual      SalePrice
# 0         Ex  241000.000000
# 1         Fa  123573.354167
# 2         Gd  215860.714286
# 3         Po  100166.666667
# 4         TA  185989.676876

# %%
sim[["GarageCond","SalePrice"]].groupby(["GarageCond"],as_index=False).mean()
# Out:
#   GarageCond      SalePrice
# 0         Ex  124000.000000
# 1         Fa  114654.028571
# 2         Gd  179930.000000
# 3         Po  108500.000000
# 4         TA  186404.109008

# %%
title_mapping={"EX":5,"Gd":4,"TA":3, "Fa":2, "Po":1}
for dataset in combine:
    dataset["GarageQual"]=dataset["GarageQual"].map(title_mapping)
    dataset["GarageQual"]=dataset["GarageQual"].fillna(0)
sim.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1200  1201          20       RL         71.0     9353   Pave      Reg
# 397    398          60       RL         69.0     7590   Pave      Reg
# 327    328          20       RL         80.0    11600   Pave      Reg
# 664    665          20       RL         49.0    20896   Pave      IR2
# 1325  1326          30       RM         40.0     3636   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1200         Lvl    AllPub    Inside  ...             0         0           0
# 397          Lvl    AllPub    Inside  ...             0         0           0
# 327          Lvl    AllPub    Inside  ...             0         0           0
# 664          Lvl    AllPub   CulDSac  ...             0         0           0
# 1325         Lvl    AllPub    Inside  ...           100         0           0
#
#      PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
title_mapping={"EX":5,"Gd":4,"TA":3, "Fa":2, "Po":1}
for dataset in combine:
    dataset["GarageCond"]=dataset["GarageCond"].map(title_mapping)
    dataset["GarageCond"]=dataset["GarageCond"].fillna(0)
sim.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 915    916         160       RM         21.0     2001   Pave      Reg
# 1368  1369         120       RM          NaN     4435   Pave      Reg
# 588    589          20       RL         65.0    25095   Pave      IR1
# 601    602          50       RM         50.0     9000   Pave      Reg
# 890    891          50       RL         60.0     8064   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 915          Lvl    AllPub    Inside  ...             0         0           0
# 1368         Lvl    AllPub    Inside  ...             0         0           0
# 588          Low    AllPub    Inside  ...             0         0          60
# 601          Bnk    AllPub    Inside  ...             0         0         126
# 890          Lvl    AllPub    Corner  ...             0         0           0
#
#      PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
for dataset in combine:
    dataset["Gagage"]=dataset["GarageQual"]+dataset["GarageCond"]
sim[["Gagage","SalePrice"]].groupby(["Gagage"],as_index=False).mean().sort_values(by="SalePrice",ascending=False)
# Out:
#    Gagage      SalePrice
# 7     8.0  232967.500000
# 5     6.0  186982.903577
# 2     3.0  186800.000000
# 6     7.0  185178.666667
# 4     5.0  127426.615385
# 3     4.0  112894.350000
# 0     0.0  103815.662651
# 1     2.0  100166.666667

# %%
sim[["GarageQual","SalePrice"]].groupby(["GarageQual"],as_index=False).mean()
# Out:
#    GarageQual      SalePrice
# 0         0.0  108234.523810
# 1         1.0  100166.666667
# 2         2.0  123573.354167
# 3         3.0  185989.676876
# 4         4.0  215860.714286

# %%
plt.figure(figsize=(14,8))
sns.heatmap(sim.isnull(), yticklabels=False, cmap='viridis')
plt.show()

# %%
sim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1455 entries, 0 to 1459
# Data columns (total 78 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1455 non-null   int64
#  1   MSSubClass     1455 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1196 non-null   float64
#  4   LotArea        1455 non-null   int64
#  5   Street         1455 non-null   object
#  6   LotShape       1455 non-null   object
#  7   LandContour    1455 non-null   object
#  8   Utilities      1455 non-null   object
#  9   LotConfig      1455 non-null   object
#  10  LandSlope      1455 non-null   object
#  11  Neighborhood   1455 non-null   object
#  12  Condition1     1455 non-null   object
#  13  Condition2     1455 non-null   object
#  14  BldgType       1455 non-null   object
#  15  HouseStyle     1455 non-null   object
#  16  OverallQual    1455 non-null   int64
# ...

# %%
sim=sim.drop("Fireplaces",axis=1)

# %%
sim=sim.drop("FireplaceQu",axis=1)

# %%
sim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1455 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1455 non-null   int64
#  1   MSSubClass     1455 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1196 non-null   float64
#  4   LotArea        1455 non-null   int64
#  5   Street         1455 non-null   object
#  6   LotShape       1455 non-null   object
#  7   LandContour    1455 non-null   object
#  8   Utilities      1455 non-null   object
#  9   LotConfig      1455 non-null   object
#  10  LandSlope      1455 non-null   object
#  11  Neighborhood   1455 non-null   object
#  12  Condition1     1455 non-null   object
#  13  Condition2     1455 non-null   object
#  14  BldgType       1455 non-null   object
#  15  HouseStyle     1455 non-null   object
#  16  OverallQual    1455 non-null   int64
# ...

# %%
sim=sim.drop("Gagage",axis=1)

# %%
sim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1455 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1455 non-null   int64
#  1   MSSubClass     1455 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1196 non-null   float64
#  4   LotArea        1455 non-null   int64
#  5   Street         1455 non-null   object
#  6   LotShape       1455 non-null   object
#  7   LandContour    1455 non-null   object
#  8   Utilities      1455 non-null   object
#  9   LotConfig      1455 non-null   object
#  10  LandSlope      1455 non-null   object
#  11  Neighborhood   1455 non-null   object
#  12  Condition1     1455 non-null   object
#  13  Condition2     1455 non-null   object
#  14  BldgType       1455 non-null   object
#  15  HouseStyle     1455 non-null   object
#  16  OverallQual    1455 non-null   int64
# ...

# %%
plt.figure(figsize=(20,8))
train_df.corr()['SalePrice'].sort_values()[:-1].plot(kind='bar')
plt.show()

# %%
sim[["RoofStyle","SalePrice"]].groupby(["RoofStyle"],as_index=False).mean()
# Out:
#   RoofStyle      SalePrice
# 0      Flat  194690.000000
# 1     Gable  170972.100000
# 2   Gambrel  148909.090909
# 3       Hip  214387.042553
# 4   Mansard  180568.428571
# 5      Shed  225000.000000

# %%
sim[["RoofMatl","SalePrice"]].groupby(["RoofMatl"],as_index=False).mean()
# Out:
#   RoofMatl      SalePrice
# 0  CompShg  178795.820405
# 1  Membran  241500.000000
# 2    Metal  180000.000000
# 3     Roll  137000.000000
# 4  Tar&Grv  185406.363636
# 5  WdShake  241400.000000
# 6  WdShngl  317300.000000

# %%
sim=sim.drop("RoofStyle",axis=1)

# %%
sim=sim.drop("RoofMatl",axis=1)

# %%
sim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1455 entries, 0 to 1459
# Data columns (total 73 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1455 non-null   int64
#  1   MSSubClass     1455 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1196 non-null   float64
#  4   LotArea        1455 non-null   int64
#  5   Street         1455 non-null   object
#  6   LotShape       1455 non-null   object
#  7   LandContour    1455 non-null   object
#  8   Utilities      1455 non-null   object
#  9   LotConfig      1455 non-null   object
#  10  LandSlope      1455 non-null   object
#  11  Neighborhood   1455 non-null   object
#  12  Condition1     1455 non-null   object
#  13  Condition2     1455 non-null   object
#  14  BldgType       1455 non-null   object
#  15  HouseStyle     1455 non-null   object
#  16  OverallQual    1455 non-null   int64
# ...

# %%
sim[["MSZoning","SalePrice"]].groupby(["MSZoning"],as_index=False).mean()
# Out:
#   MSZoning      SalePrice
# 0  C (all)   74528.000000
# 1       FV  214014.061538
# 2       RH  131558.375000
# 3       RL  189310.726003
# 4       RM  126316.830275

# %%
sim[["Street","SalePrice"]].groupby(["Street"],as_index=False).mean()
# Out:
#   Street      SalePrice
# 0   Grvl  130190.500000
# 1   Pave  179756.484472

# %%
sim=sim.drop("Street",axis=1)

# %%
sim[["LotShape","SalePrice"]].groupby(["LotShape"],as_index=False).mean()
# Out:
#   LotShape      SalePrice
# 0      IR1  202117.810417
# 1      IR2  239833.365854
# 2      IR3  222262.777778
# 3      Reg  164754.818378

# %%
sim[["LandContour","SalePrice"]].groupby(["LandContour"],as_index=False).mean()
# Out:
#   LandContour      SalePrice
# 0         Bnk  142831.564516
# 1         HLS  231533.940000
# 2         Low  203661.111111
# 3         Lvl  178641.342770
