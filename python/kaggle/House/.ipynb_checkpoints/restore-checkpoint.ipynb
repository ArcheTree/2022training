# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import numpy as np
print(pd.__version__ , sns.__version__,np.__version__)
# Out:
# 1.4.4 0.12.0 1.23.2

# %%
train_df=pd.read_csv("data/train.csv")
test_df=pd.read_csv("data/test.csv")
print(train_df.shape,test_df.shape)
# Out:
# (1460, 81) (1459, 80)

# %%
combine=[train_df,test_df]
for dataset in combine:
    print(dataset.isna().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.heatmap(train_df.isnull(), yticklabels=False, cmap='viridis')
plt.show()

# %%
all_data_na = (train_df.isnull().sum()/len(train_df))*100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:15]
missing_data = pd.DataFrame({'Missing Data' : all_data_na})
missing_data
# Out:
#               Missing Data
# PoolQC           99.520548
# MiscFeature      96.301370
# Alley            93.767123
# Fence            80.753425
# FireplaceQu      47.260274
# LotFrontage      17.739726
# GarageType        5.547945
# GarageYrBlt       5.547945
# GarageFinish      5.547945
# GarageQual        5.547945
# GarageCond        5.547945
# BsmtExposure      2.602740
# BsmtFinType2      2.602740
# BsmtFinType1      2.534247
# BsmtCond          2.534247

# %%
fig,ax = plt.subplots(figsize=(14,8))
sns.barplot(x=all_data_na.index ,y=all_data_na)
plt.xticks(rotation = 90)
plt.xlabel('Features')
plt.ylabel('Ratio of Missing Values')
plt.title('Missing Values in Training Set (Ratio)')
plt.show()

# %%
plt.figure(figsize=(14,8))
train_df.corr()['SalePrice'].sort_values()[:-1].plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.distplot(train_df['SalePrice'], kde=True, bins=50)
plt.show()
# Out:
# C:\Users\KB\AppData\Local\Temp\ipykernel_6624\328497871.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df['SalePrice'], kde=True, bins=50)

# %%
fig, axes = plt.subplots(1,2, figsize=(18,8))
sns.scatterplot(x = 'SalePrice', y= 'YearBuilt', data=train_df, ax=axes[0])
sns.scatterplot(x = 'SalePrice', y='YearRemodAdd', data=train_df, ax=axes[1])
axes[0].set_title('SalePrice vs YearBuilt')
axes[1].set_title('SalePrice vs Year Remodeled')
plt.show()

# %%
train_df[train_df["SalePrice"]>600000]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 898       3   2010       New        Partial     611657
# 1169      7   2006        WD         Normal     625000
# 1182      7   2007        WD        Abnorml     745000
#
# [4 rows x 81 columns]

# %%
train_df=train_df.drop(index=[691,898,1169,1182])

# %%
plt.figure(figsize=(14,8))
sns.distplot(train_df['SalePrice'], kde=True, bins=50)
plt.show()
# Out:
# C:\Users\KB\AppData\Local\Temp\ipykernel_6624\328497871.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df['SalePrice'], kde=True, bins=50)

# %%
fig,ax = plt.subplots(1, figsize=(14,8))
sns.countplot(data = train_df, x='GarageCars')
plt.show()

# %%
fig = plt.subplots(1, figsize=(14,8))
sns.histplot(x=train_df['GrLivArea'],  bins=60)
plt.show()

# %%
sim=train_df.drop("PoolQC",axis=1)

# %%
sim=sim.drop("Alley",axis=1)

# %%
sim=sim.drop("Fence",axis=1)

# %%
all_data_na = (sim.isnull().sum()/len(sim))*100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:15]
missing_data = pd.DataFrame({'Missing Data' : all_data_na})
missing_data
# Out:
#               Missing Data
# MiscFeature      96.291209
# FireplaceQu      47.390110
# LotFrontage      17.788462
# GarageType        5.563187
# GarageYrBlt       5.563187
# GarageFinish      5.563187
# GarageQual        5.563187
# GarageCond        5.563187
# BsmtExposure      2.609890
# BsmtFinType2      2.609890
# BsmtQual          2.541209
# BsmtCond          2.541209
# BsmtFinType1      2.541209
# MasVnrType        0.549451
# MasVnrArea        0.549451

# %%
sim=sim.drop("MiscFeature",axis=1)

# %%
sim=sim.drop("FireplaceQu",axis=1)

# %%
all_data_na = (sim.isnull().sum()/len(sim))*100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:15]
missing_data = pd.DataFrame({'Missing Data' : all_data_na})
missing_data
# Out:
#               Missing Data
# LotFrontage      17.788462
# GarageType        5.563187
# GarageYrBlt       5.563187
# GarageFinish      5.563187
# GarageQual        5.563187
# GarageCond        5.563187
# BsmtExposure      2.609890
# BsmtFinType2      2.609890
# BsmtQual          2.541209
# BsmtCond          2.541209
# BsmtFinType1      2.541209
# MasVnrType        0.549451
# MasVnrArea        0.549451
# Electrical        0.068681

# %%
sim.corr()['SalePrice'].sort_values(ascending=False)[1:]
# Out:
# OverallQual      0.798004
# GrLivArea        0.691034
# GarageCars       0.651630
# GarageArea       0.634058
# TotalBsmtSF      0.605791
# 1stFlrSF         0.596491
# FullBath         0.558121
# YearBuilt        0.539240
# TotRmsAbvGrd     0.528314
# YearRemodAdd     0.526217
# GarageYrBlt      0.502955
# Fireplaces       0.464401
# MasVnrArea       0.450840
# BsmtFinSF1       0.360712
# LotFrontage      0.332741
# OpenPorchSF      0.329547
# WoodDeckSF       0.324530
# 2ndFlrSF         0.293729
# HalfBath         0.279427
# LotArea          0.261000
# BsmtFullBath     0.231081
# BsmtUnfSF        0.229938
# BedroomAbvGr     0.162933
# ScreenPorch      0.123285
# MoSold           0.062310
# 3SsnPorch        0.049468
# PoolArea         0.029813
# BsmtFinSF2      -0.006743
# MiscVal         -0.020869
# LowQualFinSF    -0.024955
# YrSold          -0.025256
# Id              -0.034198
# BsmtHalfBath    -0.035687
# OverallCond     -0.077834
# MSSubClass      -0.087090
# EnclosedPorch   -0.129846
# KitchenAbvGr    -0.140343
# Name: SalePrice, dtype: float64

# %%
title_mapping={"EX":5,"Gd":4,"TA":3, "Fa":2, "Po":1}
for dataset in combine:
    dataset["GarageQual"]=dataset["GarageQual"].map(title_mapping)
    dataset["GarageQual"]=dataset["GarageQual"].fillna(0)
sim.sample(5)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 808  809          80       RL         85.0    13400   Pave      Reg
# 358  359          80       RL         92.0     6930   Pave      IR1
# 959  960         160       FV         24.0     2572   Pave      Reg
# 512  513          20       RL         70.0     9100   Pave      Reg
# 645  646          20       RL          NaN    10530   Pave      IR1
#
#     LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 808         Lvl    AllPub    Inside  ...             0         0           0
# 358         Lvl    AllPub    Inside  ...           294         0           0
# 959         Lvl    AllPub       FR2  ...             0         0           0
# 512         Lvl    AllPub    Corner  ...             0         0           0
# 645         Lvl    AllPub    Corner  ...            40         0           0
#
#     PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 808        0       0      6    2006        WD         Normal     159950
# 358        0       0      7    2006        WD        Abnorml     130000
# 959        0       0      5    2010        WD         Normal     155000
# 512        0       0      7    2006        WD         Normal     129900
# 645        0       0      3    2007        WD         Normal     143250
#
# [5 rows x 76 columns]

# %%
title_mapping={"EX":5,"Gd":4,"TA":3, "Fa":2, "Po":1}
for dataset in combine:
    dataset["GarageCond"]=dataset["GarageCond"].map(title_mapping)
    dataset["GarageCond"]=dataset["GarageCond"].fillna(0)
sim.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1124  1125          80       RL          NaN     9125   Pave      IR1
# 314    315          70       RM         60.0     9600   Pave      Reg
# 1085  1086          85       RL         73.0     9069   Pave      Reg
# 852    853          75       RL         53.0     7128   Pave      Reg
# 802    803          60       RL         63.0     8199   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1124         Lvl    AllPub    Inside  ...             0         0           0
# 314          Lvl    AllPub    Inside  ...           234         0           0
# 1085         Lvl    AllPub    Inside  ...             0         0           0
# 852          Lvl    AllPub    Inside  ...             0         0         126
# 802          Lvl    AllPub    Inside  ...             0         0           0
#
#      PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 1124        0       0      7    2007        WD         Normal     163900
# 314         0       0      8    2006        WD         Normal     178000
# 1085        0       0      4    2010        WD         Normal     147000
# 852         0       0      8    2007        WD         Normal     164000
# 802         0       0     10    2008        WD         Normal     189000
#
# [5 rows x 76 columns]

# %%
title_mapping={"Fin":6,"RFn":5,"Unf":3}
for dataset in combine:
    dataset["GarageFinish"]=dataset["GarageFinish"].map(title_mapping)
    dataset["GarageFinish"]=dataset["GarageFinish"].fillna(0)
sim.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1366  1367          60       RL         68.0     9179   Pave      IR1
# 407    408          70       RL         63.0    15576   Pave      Reg
# 275    276          50       RL         55.0     7264   Pave      Reg
# 1234  1235          70       RH         55.0     8525   Pave      Reg
# 1315  1316          60       RL         85.0    11075   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1366         Lvl    AllPub    Inside  ...             0         0           0
# 407          Lvl    AllPub    Inside  ...           160         0           0
# 275          Lvl    AllPub    Inside  ...             0         0         144
# 1234         Bnk    AllPub    Inside  ...             0         0           0
# 1315         Lvl    AllPub    Inside  ...             0         0           0
#
#      PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 1366        0       0      6    2008        WD        Abnorml     193000
# 407         0       0      3    2008        WD         Normal     177000
# 275         0       0     10    2009        WD         Normal     205000
# 1234        0       0     11    2008        WD        Abnorml     130000
# 1315        0       0      6    2008        WD         Normal     206900
#
# [5 rows x 76 columns]

# %%
title_mapping={"BuiltIn":8,"Attchd":7,"Basment":5,"2Types" : 4,"Detchd":3, "CarPort" : 1}
for dataset in combine:
    dataset["GarageType"]=dataset["GarageType"].map(title_mapping)
    dataset["GarageType"]=dataset["GarageType"].fillna(0)
sim.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1267  1268          20       RL         89.0    13214   Pave      IR1
# 203    204         120       RM          NaN     4438   Pave      Reg
# 210    211          30       RL         67.0     5604   Pave      Reg
# 422    423          20       RL        100.0    21750   Pave      Reg
# 1368  1369         120       RM          NaN     4435   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1267         HLS    AllPub    Inside  ...             0         0           0
# 203          Lvl    AllPub    Inside  ...             0         0           0
# 210          Lvl    AllPub    Inside  ...            96         0           0
# 422          HLS    AllPub    Inside  ...             0         0           0
# 1368         Lvl    AllPub    Inside  ...             0         0           0
#
#      PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 1267        0       0      5    2010        WD         Normal     378500
# 203         0       0      1    2008        WD         Normal     149000
# 210         0       0      4    2008        WD         Normal      98000
# 422         0       0      2    2008        WD         Normal     113000
# 1368        0       0      6    2009        WD         Normal     144000
#
# [5 rows x 76 columns]

# %%
for dataset in combine:
    dataset["Gagagepoint"]=dataset["GarageQual"]+dataset["GarageCond"]+dataset["GarageType"]+dataset["GarageFinish"]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 train_df[["Gagagepoint","SalePrice"]].groupby(["GarageQual"],as_index=False).mean()
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:5859, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Gagagepoint'] not in index"
