# %%
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
print(tf.__version__)
# Out:
# 2.10.0

# %%
print(pd.__version__)
print(sns.__version__)
# Out:
# 1.4.4
# 0.12.0

# %%
#mng데이터 로드
#shape => (columns,rows) -> 나옴
dataset=sns.load_dataset("mpg")
dataset.shape
# Out:
# (398, 9)

# %%
#결측치 처리 -빈칸 수 처리
dataset.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
#또다른 결측지 방법
dataset.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
#결측치 삭제
dataset=dataset.dropna()
dataset.shape
# Out:
# (392, 9)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
#문자 데이터 처리
#ex)name 삭제처리
dataset.pop("name")
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 393              ford mustang gl
# 394                    vw pickup
# 395                dodge rampage
# 396                  ford ranger
# 397                   chevy s-10
# Name: name, Length: 392, dtype: object

# %%
dataset.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %%
#origin 열은 범주형 원-핫 인코딩으로 변환
origin=dataset.pop("origin")

# %%
dataset["usa"]=(origin=="usa")*1.0
dataset["europe"]=(origin=="europe")*1.0
dataset["japan"]=(origin=="japan")*1.0
dataset.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  usa  europe  japan
# 393          82  1.0     0.0    0.0
# 394          82  0.0     1.0    0.0
# 395          82  1.0     0.0    0.0
# 396          82  1.0     0.0    0.0
# 397          82  1.0     0.0    0.0

# %%
#학습(8)-(train_dataset) 후 평가(2)-(test_dataset)
train_dataset=dataset.sample(frac=0.8,random_state=42)
rest_dataset=dataset.drop(train_dataset.index)
train_dataset.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 218  36.0          4          79.0        58.0    1825          18.6
# 281  19.8          6         200.0        85.0    2990          18.2
# 342  30.0          4         135.0        84.0    2385          12.9
# 238  33.5          4          98.0        83.0    2075          15.9
# 209  19.0          4         120.0        88.0    3270          21.9
#
#      model_year  usa  europe  japan
# 218          77  0.0     1.0    0.0
# 281          79  1.0     0.0    0.0
# 342          81  1.0     0.0    0.0
# 238          77  1.0     0.0    0.0
# 209          76  0.0     1.0    0.0

# %%
sns.pairplot(train_dataset[["mpg","cylinders","displacement","weight"]])

# %%
#기술 통계
train_state=train_dataset.describe()
train_state.pop("mpg")
train_state
# Out:
#         cylinders  displacement  horsepower       weight  acceleration  \
# count  314.000000    314.000000  314.000000   314.000000    314.000000
# mean     5.531847    197.855096  105.971338  3005.745223     15.510828
# std      1.729449    106.501896   39.636557   859.060925      2.803560
# min      3.000000     68.000000   46.000000  1649.000000      8.000000
# 25%      4.000000    105.000000   76.000000  2231.000000     13.625000
# 50%      4.000000    151.000000   95.000000  2831.500000     15.500000
# 75%      8.000000    302.000000  130.000000  3641.750000     17.000000
# max      8.000000    455.000000  230.000000  4955.000000     24.800000
#
#        model_year         usa      europe       japan
# count  314.000000  314.000000  314.000000  314.000000
# mean    75.910828    0.624204    0.171975    0.203822
# std      3.688989    0.485101    0.377961    0.403481
# min     70.000000    0.000000    0.000000    0.000000
# 25%     73.000000    0.000000    0.000000    0.000000
# 50%     76.000000    1.000000    0.000000    0.000000
# 75%     79.000000    1.000000    0.000000    0.000000
# max     82.000000    1.000000    1.000000    1.000000

# %%
#transpose() - 행과열을 바꿈
train_state=train_state.transpose()
train_state
# Out:
#               count         mean         std     min       25%     50%  \
# cylinders     314.0     5.531847    1.729449     3.0     4.000     4.0
# displacement  314.0   197.855096  106.501896    68.0   105.000   151.0
# horsepower    314.0   105.971338   39.636557    46.0    76.000    95.0
# weight        314.0  3005.745223  859.060925  1649.0  2231.000  2831.5
# acceleration  314.0    15.510828    2.803560     8.0    13.625    15.5
# model_year    314.0    75.910828    3.688989    70.0    73.000    76.0
# usa           314.0     0.624204    0.485101     0.0     0.000     1.0
# europe        314.0     0.171975    0.377961     0.0     0.000     0.0
# japan         314.0     0.203822    0.403481     0.0     0.000     0.0
#
#                   75%     max
# cylinders        8.00     8.0
# displacement   302.00   455.0
# horsepower     130.00   230.0
# weight        3641.75  4955.0
# acceleration    17.00    24.8
# model_year      79.00    82.0
# usa              1.00     1.0
# europe           0.00     1.0
# japan            0.00     1.0

# %%
#레이블-예측할려는 칼럼
#특성 - 다른 칼럼
#특성과 레이블을 분리한다 ->문제와 정답으로 분리

test_label=rest_dataset.pop("mpg")

# %%
train_label
# Out:
# 79     26.0
# 276    21.6
# 248    36.1
# 56     26.0
# 393    27.0
#        ...
# 218    36.0
# 281    19.8
# 342    30.0
# 238    33.5
# 209    19.0
# Name: mpg, Length: 314, dtype: float64

# %%
test_label
# Out:
# 1      15.0
# 13     14.0
# 20     25.0
# 21     24.0
# 35     17.0
#        ...
# 381    36.0
# 388    26.0
# 391    36.0
# 395    32.0
# 397    31.0
# Name: mpg, Length: 78, dtype: float64

# %%
train_dataset
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 79           4          96.0        69.0    2189          18.0          72
# 276          4         121.0       115.0    2795          15.7          78
# 248          4          91.0        60.0    1800          16.4          78
# 56           4          91.0        70.0    1955          20.5          71
# 393          4         140.0        86.0    2790          15.6          82
# ..         ...           ...         ...     ...           ...         ...
# 218          4          79.0        58.0    1825          18.6          77
# 281          6         200.0        85.0    2990          18.2          79
# 342          4         135.0        84.0    2385          12.9          81
# 238          4          98.0        83.0    2075          15.9          77
# 209          4         120.0        88.0    3270          21.9          76
#
#      usa  europe  japan
# 79   0.0     1.0    0.0
# 276  0.0     1.0    0.0
# 248  0.0     0.0    1.0
# 56   1.0     0.0    0.0
# 393  1.0     0.0    0.0
# ..   ...     ...    ...
# 218  0.0     1.0    0.0
# 281  1.0     0.0    0.0
# 342  1.0     0.0    0.0
# 238  1.0     0.0    0.0
# 209  0.0     1.0    0.0
#
# [314 rows x 9 columns]

# %%
#데이터 정규화 -연산속도 업, 예측적중률 업
#범주를 일정 수 (일반적으로 -1~1사이 [표준표차이용])로 고정시키는것(그래프는 변화X)
def norm(x):
    return(x-train_state["mean"])/train_state["std"]
normed_train_data=norm(train_dataset)
normed_test_train_data=norm(rest_dataset)

# %%
normed_test_train_data
# Out:
#      cylinders  displacement  horsepower    weight  acceleration  model_year  \
# 1     1.427132      1.428565    1.489248  0.800007     -1.430620   -1.602290
# 13    1.427132      2.414463    3.003002  0.093422     -1.965654   -1.602290
# 20   -0.885743     -0.824916   -0.478632 -0.388500      0.709517   -1.602290
# 21   -0.885743     -0.853084   -0.402945 -0.670203     -0.360552   -1.602290
# 35    0.270695      0.489615   -0.150652  0.376289     -0.003862   -1.331213
# ..         ...           ...         ...       ...           ...         ...
# 381  -0.885743     -0.853084   -0.781383 -0.932117     -0.360552    1.650635
# 388  -0.885743     -0.392999   -0.352486 -0.489773     -0.360552    1.650635
# 391  -0.885743     -0.590178   -0.554320 -0.740047     -0.895586    1.650635
# 395  -0.885743     -0.590178   -0.554320 -0.827351     -1.394951    1.650635
# 397  -0.885743     -0.740410   -0.604778 -0.332625      1.387226    1.650635
#
#           usa    europe     japan
# 1    0.774676 -0.455006 -0.505158
# 13   0.774676 -0.455006 -0.505158
# 20  -1.286751  2.190772 -0.505158
# 21  -1.286751  2.190772 -0.505158
# 35   0.774676 -0.455006 -0.505158
# ..        ...       ...       ...
# 381 -1.286751 -0.455006  1.973274
# 388  0.774676 -0.455006 -0.505158
# 391  0.774676 -0.455006 -0.505158
# 395  0.774676 -0.455006 -0.505158
# 397  0.774676 -0.455006 -0.505158
#
# [78 rows x 9 columns]

# %%
normed_train_data.tail()
# Out:
#      cylinders  displacement  horsepower    weight  acceleration  model_year  \
# 218  -0.885743     -1.115990   -1.210280 -1.374460      1.101875    0.295249
# 281   0.270695      0.020140   -0.529091 -0.018328      0.959199    0.837404
# 342  -0.885743     -0.590178   -0.554320 -0.722586     -0.931255    1.379558
# 238  -0.885743     -0.937590   -0.579549 -1.083445      0.138814    0.295249
# 209  -0.885743     -0.731021   -0.453403  0.307609      2.278950    0.024172
#
#           usa    europe     japan
# 218 -1.286751  2.190772 -0.505158
# 281  0.774676 -0.455006 -0.505158
# 342  0.774676 -0.455006 -0.505158
# 238  0.774676 -0.455006 -0.505158
# 209 -1.286751  2.190772 -0.505158

# %%
len(train_dataset)
# Out:
# 314

# %%
#모델만들기  mae(오차) mae(제곱 표준편차?)
def build_model():
    model=keras.Sequential([
        layers.Dense(64,input_shape=[len(train_dataset.keys())], activation="relu"),
        layers.Dense(64,activation="relu"),
        layers.Dense(1)
    ])
    optimizer=tf.keras.optimizers.RMSprop(0.001)  #오답처리 알고리즘
    model.compile(loss="mse", optimizer=optimizer, metrics=["mae","mse"])
    return model

# %%
#모델 확인
model=build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 64)                640
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
#모델 훈련
# 1000번 반복 ->에포크(별칭)
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self,epoch,logs):
        if epoch%100==0: 
            print("")
        print(',',end="")
EPOCHS=1000
model=build_model()
history=model.fit(
    normed_train_data,train_label,
    epochs=EPOCHS,validation_split=0.2,verbose=0,
    callbacks=[PrintDot()]
)
# Out:
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,

# %%
hist=pd.DataFrame(history.history)
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse
# 995  2.596299  0.989879  2.596299  4.975587  1.848381  4.975587
# 996  2.738379  1.061473  2.738379  4.914537  1.813719  4.914537
# 997  2.546395  1.010536  2.546395  4.825803  1.802997  4.825803
# 998  2.495500  0.996421  2.495500  4.603568  1.745763  4.603568
# 999  2.695028  1.044168  2.695028  5.238563  1.867668  5.238563

# %%
# 학습 1000번이 가성비 효율이 좋은가?
# 학습 진행하며 오차율을 시각화
def sns_hist(history):
    hist=pd.DataFrame(history.history)
    hist['epoch']=history.epoch
    sns.lineplot(data=hist,x="epoch",y="mae")
    sns.lineplot(data=hist,x="epoch",y="mse")
sns_hist(history)

# %%
#model.fit을 수정해서 검증 점수가 향상되지 않으면 자동으로 훈련을 멈추도록 하는 것으로 수정(val_Loss기준)
model=build_model()
early_stop=keras.callbacks.EarlyStopping(monitor="val_loss",patience=10)
history=model.fit(
    normed_train_data,train_label,
    epochs=EPOCHS,validation_split=0.2,verbose=0,
    callbacks=[PrintDot(),early_stop]
)
# Out:
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,

# %%
history=model.fit(
    normed_train_data,train_label,
    epochs=EPOCHS,validation_split=0.2,verbose=1,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.0826 - mae: 1.7298 - mse: 6.0826 - val_loss: 4.4117 - val_mae: 1.6124 - val_mse: 4.4117
# Epoch 2/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.0752 - mae: 1.7158 - mse: 6.0752 - val_loss: 4.4736 - val_mae: 1.5850 - val_mse: 4.4736
# Epoch 3/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.4323 - mae: 1.7619 - mse: 6.4323 - val_loss: 4.1393 - val_mae: 1.5545 - val_mse: 4.1393
# Epoch 4/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.0563 - mae: 1.7309 - mse: 6.0563 - val_loss: 4.3113 - val_mae: 1.6038 - val_mse: 4.3113
# Epoch 5/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.9890 - mae: 1.7148 - mse: 5.9890 - val_loss: 4.1011 - val_mae: 1.5716 - val_mse: 4.1011
# Epoch 6/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.0961 - mae: 1.7467 - mse: 6.0961 - val_loss: 4.2793 - val_mae: 1.6228 - val_mse: 4.2793
# Epoch 7/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.9571 - mae: 1.7155 - mse: 5.9571 - val_loss: 4.2577 - val_mae: 1.5568 - val_mse: 4.2577
# Epoch 8/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.9911 - mae: 1.7003 - mse: 5.9911 - val_loss: 4.1030 - val_mae: 1.5464 - val_mse: 4.1030
# Epoch 9/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.1495 - mae: 1.7494 - mse: 6.1495 - val_loss: 4.0284 - val_mae: 1.5648 - val_mse: 4.0284
# Epoch 10/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.7641 - mae: 1.6929 - mse: 5.7641 - val_loss: 4.5212 - val_mae: 1.5849 - val_mse: 4.5212
# Epoch 11/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 5.9410 - mae: 1.6833 - mse: 5.9410 - val_loss: 4.2481 - val_mae: 1.5681 - val_mse: 4.2481
# Epoch 12/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.8869 - mae: 1.7056 - mse: 5.8869 - val_loss: 4.2037 - val_mae: 1.6074 - val_mse: 4.2037
# Epoch 13/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.2122 - mae: 1.7470 - mse: 6.2122 - val_loss: 3.9625 - val_mae: 1.5522 - val_mse: 3.9625
# Epoch 14/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 5.9132 - mae: 1.7073 - mse: 5.9132 - val_loss: 4.0322 - val_mae: 1.5483 - val_mse: 4.0322
# Epoch 15/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 6.0702 - mae: 1.7264 - mse: 6.0702 - val_loss: 4.2405 - val_mae: 1.5460 - val_mse: 4.2405
# Epoch 16/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.9476 - mae: 1.7225 - mse: 5.9476 - val_loss: 4.6495 - val_mae: 1.6101 - val_mse: 4.6495
# Epoch 17/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.9206 - mae: 1.7092 - mse: 5.9206 - val_loss: 4.1584 - val_mae: 1.5853 - val_mse: 4.1584
# Epoch 18/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.0674 - mae: 1.7214 - mse: 6.0674 - val_loss: 4.2418 - val_mae: 1.5622 - val_mse: 4.2418
# Epoch 19/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.0190 - mae: 1.7318 - mse: 6.0190 - val_loss: 4.4167 - val_mae: 1.5708 - val_mse: 4.4167
# Epoch 20/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.9371 - mae: 1.7117 - mse: 5.9371 - val_loss: 4.0447 - val_mae: 1.5620 - val_mse: 4.0447
# Epoch 21/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.1344 - mae: 1.7575 - mse: 6.1344 - val_loss: 4.1174 - val_mae: 1.5746 - val_mse: 4.1174
# Epoch 22/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 5.9182 - mae: 1.7061 - mse: 5.9182 - val_loss: 3.9426 - val_mae: 1.5489 - val_mse: 3.9426
# Epoch 23/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.9054 - mae: 1.7053 - mse: 5.9054 - val_loss: 4.4073 - val_mae: 1.5664 - val_mse: 4.4073
# Epoch 24/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 5.8874 - mae: 1.7021 - mse: 5.8874 - val_loss: 4.4263 - val_mae: 1.5963 - val_mse: 4.4263
# Epoch 25/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.9947 - mae: 1.7225 - mse: 5.9947 - val_loss: 3.9426 - val_mae: 1.5505 - val_mse: 3.9426
# Epoch 26/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 5.8397 - mae: 1.7171 - mse: 5.8397 - val_loss: 4.2414 - val_mae: 1.5529 - val_mse: 4.2414
# Epoch 27/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 5.7443 - mae: 1.6807 - mse: 5.7443 - val_loss: 4.7206 - val_mae: 1.6201 - val_mse: 4.7206
# Epoch 28/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.8716 - mae: 1.6741 - mse: 5.8716 - val_loss: 4.0327 - val_mae: 1.5385 - val_mse: 4.0327
# Epoch 29/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 5.9078 - mae: 1.6894 - mse: 5.9078 - val_loss: 4.3103 - val_mae: 1.5357 - val_mse: 4.3103
# Epoch 30/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.7305 - mae: 1.6741 - mse: 5.7305 - val_loss: 3.9683 - val_mae: 1.5421 - val_mse: 3.9683
# Epoch 31/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 6.1738 - mae: 1.7000 - mse: 6.1738 - val_loss: 3.9530 - val_mae: 1.5517 - val_mse: 3.9530
# Epoch 32/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 5.8748 - mae: 1.6986 - mse: 5.8748 - val_loss: 4.0225 - val_mae: 1.5570 - val_mse: 4.0225

# %%
history=model.fit(
    normed_train_data,train_label,
    epochs=EPOCHS,validation_split=0.2,verbose=2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/1000
# 8/8 - 0s - loss: 6.2039 - mae: 1.7551 - mse: 6.2039 - val_loss: 3.9918 - val_mae: 1.5217 - val_mse: 3.9918 - 56ms/epoch - 7ms/step
# Epoch 2/1000
# 8/8 - 0s - loss: 5.8149 - mae: 1.6606 - mse: 5.8149 - val_loss: 3.9716 - val_mae: 1.5682 - val_mse: 3.9716 - 24ms/epoch - 3ms/step
# Epoch 3/1000
# 8/8 - 0s - loss: 5.8931 - mae: 1.6886 - mse: 5.8931 - val_loss: 4.4954 - val_mae: 1.5589 - val_mse: 4.4954 - 22ms/epoch - 3ms/step
# Epoch 4/1000
# 8/8 - 0s - loss: 5.9847 - mae: 1.7005 - mse: 5.9847 - val_loss: 4.1455 - val_mae: 1.5307 - val_mse: 4.1455 - 23ms/epoch - 3ms/step
# Epoch 5/1000
# 8/8 - 0s - loss: 5.8494 - mae: 1.7004 - mse: 5.8494 - val_loss: 4.0461 - val_mae: 1.5673 - val_mse: 4.0461 - 24ms/epoch - 3ms/step
# Epoch 6/1000
# 8/8 - 0s - loss: 5.9717 - mae: 1.7031 - mse: 5.9717 - val_loss: 3.9829 - val_mae: 1.5622 - val_mse: 3.9829 - 23ms/epoch - 3ms/step
# Epoch 7/1000
# 8/8 - 0s - loss: 5.7336 - mae: 1.6629 - mse: 5.7336 - val_loss: 4.0752 - val_mae: 1.5320 - val_mse: 4.0752 - 24ms/epoch - 3ms/step
# Epoch 8/1000
# 8/8 - 0s - loss: 5.6681 - mae: 1.6565 - mse: 5.6681 - val_loss: 4.0256 - val_mae: 1.5696 - val_mse: 4.0256 - 22ms/epoch - 3ms/step
# Epoch 9/1000
# 8/8 - 0s - loss: 5.7958 - mae: 1.6985 - mse: 5.7958 - val_loss: 4.2524 - val_mae: 1.5489 - val_mse: 4.2524 - 24ms/epoch - 3ms/step
# Epoch 10/1000
# 8/8 - 0s - loss: 5.8584 - mae: 1.6791 - mse: 5.8584 - val_loss: 3.8442 - val_mae: 1.4961 - val_mse: 3.8442 - 23ms/epoch - 3ms/step
# Epoch 11/1000
# 8/8 - 0s - loss: 5.7598 - mae: 1.6643 - mse: 5.7598 - val_loss: 3.8386 - val_mae: 1.5378 - val_mse: 3.8386 - 23ms/epoch - 3ms/step
# Epoch 12/1000
# 8/8 - 0s - loss: 5.9598 - mae: 1.7271 - mse: 5.9598 - val_loss: 3.9791 - val_mae: 1.5205 - val_mse: 3.9791 - 23ms/epoch - 3ms/step
# Epoch 13/1000
# 8/8 - 0s - loss: 5.6830 - mae: 1.6644 - mse: 5.6830 - val_loss: 3.9977 - val_mae: 1.5789 - val_mse: 3.9977 - 24ms/epoch - 3ms/step
# Epoch 14/1000
# 8/8 - 0s - loss: 5.9029 - mae: 1.6955 - mse: 5.9029 - val_loss: 4.1019 - val_mae: 1.5291 - val_mse: 4.1019 - 23ms/epoch - 3ms/step
# Epoch 15/1000
# 8/8 - 0s - loss: 5.8106 - mae: 1.6960 - mse: 5.8106 - val_loss: 4.0402 - val_mae: 1.5714 - val_mse: 4.0402 - 26ms/epoch - 3ms/step
# Epoch 16/1000
# 8/8 - 0s - loss: 5.7484 - mae: 1.6621 - mse: 5.7484 - val_loss: 4.3254 - val_mae: 1.5414 - val_mse: 4.3254 - 23ms/epoch - 3ms/step
# Epoch 17/1000
# 8/8 - 0s - loss: 5.9263 - mae: 1.6730 - mse: 5.9263 - val_loss: 3.8862 - val_mae: 1.5400 - val_mse: 3.8862 - 25ms/epoch - 3ms/step
# Epoch 18/1000
# 8/8 - 0s - loss: 5.7957 - mae: 1.6745 - mse: 5.7957 - val_loss: 3.8862 - val_mae: 1.5265 - val_mse: 3.8862 - 22ms/epoch - 3ms/step
# Epoch 19/1000
# 8/8 - 0s - loss: 5.7324 - mae: 1.6761 - mse: 5.7324 - val_loss: 4.3841 - val_mae: 1.5382 - val_mse: 4.3841 - 24ms/epoch - 3ms/step
# Epoch 20/1000
# 8/8 - 0s - loss: 5.7987 - mae: 1.7085 - mse: 5.7987 - val_loss: 4.1495 - val_mae: 1.5111 - val_mse: 4.1495 - 24ms/epoch - 3ms/step
# Epoch 21/1000
# 8/8 - 0s - loss: 5.7044 - mae: 1.6611 - mse: 5.7044 - val_loss: 3.7910 - val_mae: 1.4905 - val_mse: 3.7910 - 24ms/epoch - 3ms/step
# Epoch 22/1000
# 8/8 - 0s - loss: 5.7141 - mae: 1.6705 - mse: 5.7141 - val_loss: 3.9009 - val_mae: 1.5191 - val_mse: 3.9009 - 23ms/epoch - 3ms/step
# Epoch 23/1000
# 8/8 - 0s - loss: 5.6131 - mae: 1.6460 - mse: 5.6131 - val_loss: 3.8730 - val_mae: 1.5045 - val_mse: 3.8730 - 24ms/epoch - 3ms/step
# Epoch 24/1000
# 8/8 - 0s - loss: 5.6724 - mae: 1.6503 - mse: 5.6724 - val_loss: 3.9851 - val_mae: 1.5226 - val_mse: 3.9851 - 23ms/epoch - 3ms/step
# Epoch 25/1000
# 8/8 - 0s - loss: 5.6572 - mae: 1.6461 - mse: 5.6572 - val_loss: 3.9237 - val_mae: 1.5049 - val_mse: 3.9237 - 24ms/epoch - 3ms/step
# Epoch 26/1000
# 8/8 - 0s - loss: 5.8043 - mae: 1.6703 - mse: 5.8043 - val_loss: 3.9229 - val_mae: 1.5045 - val_mse: 3.9229 - 23ms/epoch - 3ms/step
# Epoch 27/1000
# 8/8 - 0s - loss: 5.5219 - mae: 1.6297 - mse: 5.5219 - val_loss: 3.9239 - val_mae: 1.5618 - val_mse: 3.9239 - 23ms/epoch - 3ms/step
# Epoch 28/1000
# 8/8 - 0s - loss: 5.7193 - mae: 1.6703 - mse: 5.7193 - val_loss: 3.8820 - val_mae: 1.5189 - val_mse: 3.8820 - 23ms/epoch - 3ms/step
# Epoch 29/1000
# 8/8 - 0s - loss: 6.0571 - mae: 1.6855 - mse: 6.0571 - val_loss: 4.0353 - val_mae: 1.5146 - val_mse: 4.0353 - 24ms/epoch - 3ms/step
# Epoch 30/1000
# 8/8 - 0s - loss: 5.6220 - mae: 1.6596 - mse: 5.6220 - val_loss: 4.1394 - val_mae: 1.5025 - val_mse: 4.1394 - 32ms/epoch - 4ms/step
# Epoch 31/1000
# 8/8 - 0s - loss: 5.7820 - mae: 1.6668 - mse: 5.7820 - val_loss: 3.9243 - val_mae: 1.5643 - val_mse: 3.9243 - 25ms/epoch - 3ms/step

# %%
history=model.fit(
    normed_train_data,train_label,
    epochs=EPOCHS,validation_split=0.2,verbose=3,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/1000
# Epoch 2/1000
# Epoch 3/1000
# Epoch 4/1000
# Epoch 5/1000
# Epoch 6/1000
# Epoch 7/1000
# Epoch 8/1000
# Epoch 9/1000
# Epoch 10/1000
# Epoch 11/1000
# Epoch 12/1000
# Epoch 13/1000
# Epoch 14/1000
# Epoch 15/1000
# Epoch 16/1000
# Epoch 17/1000
# Epoch 18/1000
# Epoch 19/1000
# Epoch 20/1000
# Epoch 21/1000
# Epoch 22/1000
# Epoch 23/1000
# Epoch 24/1000
# Epoch 25/1000
# Epoch 26/1000
# Epoch 27/1000
# Epoch 28/1000
# Epoch 29/1000
# Epoch 30/1000
# Epoch 31/1000
# Epoch 32/1000
# Epoch 33/1000
# Epoch 34/1000

# %%
model=build_model()
early_stop=keras.callbacks.EarlyStopping(monitor="val_loss",patience=10)
history=model.fit(
    normed_train_data,train_label,
    epochs=EPOCHS,validation_split=0.2,verbose=3,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/1000
# Epoch 2/1000
# Epoch 3/1000
# Epoch 4/1000
# Epoch 5/1000
# Epoch 6/1000
# Epoch 7/1000
# Epoch 8/1000
# Epoch 9/1000
# Epoch 10/1000
# Epoch 11/1000
# Epoch 12/1000
# Epoch 13/1000
# Epoch 14/1000
# Epoch 15/1000
# Epoch 16/1000
# Epoch 17/1000
# Epoch 18/1000
# Epoch 19/1000
# Epoch 20/1000
# Epoch 21/1000
# Epoch 22/1000
# Epoch 23/1000
# Epoch 24/1000
# Epoch 25/1000
# Epoch 26/1000
# Epoch 27/1000
# Epoch 28/1000
# Epoch 29/1000
# Epoch 30/1000
# Epoch 31/1000
# Epoch 32/1000
# Epoch 33/1000
# Epoch 34/1000
# Epoch 35/1000
# Epoch 36/1000
# Epoch 37/1000
# Epoch 38/1000
# Epoch 39/1000
# Epoch 40/1000
# Epoch 41/1000
# Epoch 42/1000
# Epoch 43/1000
# Epoch 44/1000
# Epoch 45/1000
# Epoch 46/1000
# Epoch 47/1000
# Epoch 48/1000
# Epoch 49/1000
# Epoch 50/1000
# Epoch 51/1000
# Epoch 52/1000
# Epoch 53/1000
# Epoch 54/1000
# Epoch 55/1000
# Epoch 56/1000
# Epoch 57/1000
# Epoch 58/1000
# Epoch 59/1000
# Epoch 60/1000
# Epoch 61/1000
# Epoch 62/1000
# Epoch 63/1000
# Epoch 64/1000
# Epoch 65/1000
# Epoch 66/1000
# Epoch 67/1000
# Epoch 68/1000
# Epoch 69/1000
# Epoch 70/1000
# Epoch 71/1000
# Epoch 72/1000
# Epoch 73/1000
# Epoch 74/1000
# Epoch 75/1000
# Epoch 76/1000
# Epoch 77/1000
# Epoch 78/1000
# Epoch 79/1000
# Epoch 80/1000
# Epoch 81/1000
# Epoch 82/1000
# Epoch 83/1000
# Epoch 84/1000
# Epoch 85/1000
# Epoch 86/1000
# Epoch 87/1000
# Epoch 88/1000
# Epoch 89/1000
# Epoch 90/1000
# Epoch 91/1000
# Epoch 92/1000
# Epoch 93/1000
# Epoch 94/1000
# Epoch 95/1000
# Epoch 96/1000
# Epoch 97/1000
# Epoch 98/1000
# Epoch 99/1000
# Epoch 100/1000
# Epoch 101/1000
# Epoch 102/1000
# Epoch 103/1000
# Epoch 104/1000
# Epoch 105/1000
# Epoch 106/1000
# Epoch 107/1000
# Epoch 108/1000
# Epoch 109/1000
# Epoch 110/1000
# Epoch 111/1000
# Epoch 112/1000
# Epoch 113/1000
# Epoch 114/1000
# Epoch 115/1000
# Epoch 116/1000
# Epoch 117/1000
# Epoch 118/1000
# Epoch 119/1000
# Epoch 120/1000
# Epoch 121/1000
# Epoch 122/1000
# Epoch 123/1000
# Epoch 124/1000
# Epoch 125/1000
# Epoch 126/1000
# Epoch 127/1000
# Epoch 128/1000
# Epoch 129/1000

# %%
sns_hist(history)

# %%
model=build_model()
early_stop=keras.callbacks.EarlyStopping(monitor="val_loss",patience=10)
history=model.fit(
    normed_train_data,train_label,
    epochs=EPOCHS,validation_split=0.2,verbose=0,
    callbacks=[PrintDot(),early_stop]
)
# Out:
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,

# %%
sns_hist(history)

# %%
#성능평가
loss,mae,mse=model.evaluate(normed_test_train_data,test_label,verbose=2)
print("테스트 세트의 평균 절대 오차 :",mae,"MPG")
print("테스트 세트의 평균 절대 오차 : {:.2f} MPG".format(mae,mse))
# Out:
# 3/3 - 0s - loss: 6.4273 - mae: 1.8317 - mse: 6.4273 - 18ms/epoch - 6ms/step
# 테스트 세트의 평균 절대 오차 : 1.831720232963562 MPG
# 테스트 세트의 평균 절대 오차 : 1.83 MPG

# %%
#시각화해서 평가
#예측
test_predictions=model.predict(normed_test_train_data).flatten()
test_predictions
# Out:
# 3/3 [==============================] - 0s 998us/step
# array([14.858199, 15.603004, 20.85716 , 22.103128, 17.368317, 12.62925 ,
#        26.98019 , 23.554222, 25.38057 , 29.246922, 29.920355, 26.473736,
#        26.581219, 14.101639, 23.68384 , 14.099108, 14.045229, 13.050573,
#        18.418486, 13.3832  , 12.446352, 18.639427, 20.620577, 21.96355 ,
#        14.1896  , 27.893604, 17.167076, 15.841931, 16.704115, 21.390144,
#        21.436241, 18.630245, 16.333864, 15.029993, 18.847   , 18.053616,
#        19.938122, 30.599396, 21.311993, 15.828066, 31.656525, 25.352749,
#        29.849884, 22.487268, 33.838295, 19.539392, 22.210545, 21.234135,
#        18.316837, 16.842367, 29.949135, 21.396217, 22.074644, 18.255775,
#        32.343834, 32.54381 , 24.530666, 24.824924, 27.538912, 36.35453 ,
#        32.73403 , 23.457714, 33.612465, 32.035957, 34.222458, 21.693094,
#        37.067986, 36.274536, 30.999752, 24.563583, 24.441303, 24.303436,
#        36.15599 , 34.72387 , 29.2006  , 33.019978, 34.810814, 28.758541],
#       dtype=float32)

# %%
sns.regplot(x=test_label,y=test_predictions)
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
sns.residplot(x=test_label,y=test_predictions)
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
#오차분표
erroe=test_predictions-test_label
erroe.tail()
# Out:
# 381   -1.276131
# 388    3.200600
# 391   -2.980022
# 395    2.810814
# 397   -2.241459
# Name: mpg, dtype: float64

# %%
erroe.hist()
# Out:
# <AxesSubplot:>
