# %%
import pandas as pd
import matplotlib.pyplot as plt
# 노트북 안에 그래프를 그리기 위해
# %matplotlib inline
import seaborn as sns

# %%
train = pd.read_csv("data/train.csv", parse_dates=["datetime"])
train.shape
# Out:
# (10886, 12)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.7 KB

# %%
train["year"] = train["datetime"].dt.year
train["month"] = train["datetime"].dt.month
train["day"] = train["datetime"].dt.day
train["hour"] = train["datetime"].dt.hour
train["minute"] = train["datetime"].dt.minute
train["second"] = train["datetime"].dt.second
train.shape
# Out:
# (10886, 18)

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second
# 0       0       0
# 1       0       0
# ...

# %%
train.dtypes
# Out:
# datetime      datetime64[ns]
# season                 int64
# holiday                int64
# workingday             int64
# weather                int64
# temp                 float64
# atemp                float64
# humidity               int64
# windspeed            float64
# casual                 int64
# registered             int64
# count                  int64
# year                   int64
# month                  int64
# day                    int64
# hour                   int64
# minute                 int64
# second                 int64
# dtype: object

# %%
train.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# year          0
# month         0
# day           0
# hour          0
# minute        0
# second        0
# dtype: int64

# %%
year=sns.barplot(data=train, x="year", y="count")
plt.savefig("./images/year.png")

# %%
month=sns.barplot(data=train, x="month", y="count")
plt.savefig("./images/month.png")

# %%
day=sns.barplot(data=train, x="day", y="count")
plt.savefig("./images/day.png")

# %%
hour=sns.barplot(data=train, x="hour", y="count")
plt.savefig("./images/hour.png")

# %%
sns.pointplot(data=train, x="hour", y="count")
plt.savefig("./images/pp-hour.png")

# %%
sns.pointplot(data=train, x="hour", y="count", hue="workingday")
plt.savefig("./images/pp-hour-workingday.png")

# %%
train["dayofweek"] = train["datetime"].dt.dayofweek
train.sample(5)
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 3726 2011-09-06 05:00:00       3        0           1        3  22.14  25.760
# 9688 2012-10-08 01:00:00       4        1           0        1  13.94  16.665
# 8766 2012-08-07 15:00:00       3        0           1        1  32.80  37.120
# 5324 2011-12-15 22:00:00       4        0           1        1  21.32  25.000
# 938  2011-03-03 13:00:00       1        0           1        1   9.02  12.880
#
#       humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 3726        88    23.9994       1          20     21  2011      9    6     5
# 9688        87    11.0014       2          35     37  2012     10    8     1
# 8766        52     0.0000     100         206    306  2012      8    7    15
# 5324        63    22.0028       8         116    124  2011     12   15    22
# 938         25     6.0032      13          67     80  2011      3    3    13
#
#       minute  second  dayofweek
# ...

# %%
sns.pointplot(data=train, x="hour", y="count", hue="weather")
plt.savefig("./images/pp-hour-weather.png")

# %%
sns.pointplot(data=train, x="hour", y="count", hue="season")
plt.savefig("./images/pp-hour-season.png")
